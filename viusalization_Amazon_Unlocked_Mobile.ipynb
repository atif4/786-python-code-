# %%
#hide earrings 
import warnings
warnings.filterwarnings('ignore')

# EDA pamages 
import pandas as pd
import numpy as np

# Data Viz pakages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\haier\\Python\\TEXT_DATA_PREPROCESSING\\Data_sets\\text_data_preprocessed_Amazon_Unlocked_Mobile.csv")

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                             Product Id Company Name  Price  \
# 0    clear clean esn sprint epic g galaxy sphdfront...      samsung    199
# 1    clear clean esn sprint epic g galaxy sphdfront...      samsung    199
# 2    clear clean esn sprint epic g galaxy sphdfront...      samsung    199
# 3    clear clean esn sprint epic g galaxy sphdfront...      samsung    199
# 4    clear clean esn sprint epic g galaxy sphdfront...      samsung    199
# ..                                                 ...          ...    ...
# 318  gunlocked huawei honor tft ltps screen x pixel...       huawei    161
# 319  cell phones unlocked android mtk quad core rom...       juning     89
# 320  cell phones unlocked android mtk quad core rom...       juning     89
# 321  cell phones unlocked android mtk quad core rom...       juning     89
# 322  cell phones unlocked android mtk quad core rom...       juning     89
#
# ...

# %%
def get_scatter_plot(c_id1,c_id2):
    # Scatter plot with day against tip
    plt.scatter(df[c_id1], df[c_id2])
    # Adding Title to the Plot
    plt.title("Scatter Plot")
    # Setting the X and Y labels
    plt.xlabel(c_id1)
    plt.ylabel(c_id2)
    plt.xticks(rotation = 90)
    plt.show()

# %%
get_scatter_plot('Company Name','Price')

# %%
get_scatter_plot('Company Name','Rating')

# %%
get_scatter_plot('Company Name', 'Review Votes')

# %%
def get_scatter_plot2(c_id1,c_id2,c_id3,c_id4):
    # Scatter plot with day against tip
    plt.scatter(df[c_id1], df[c_id2], c = df[c_id3], s = df[c_id4])
    # Adding Title to the Plot
    plt.title("Scatter Plot")
    # Setting the X and Y labels
    plt.xlabel(c_id1)
    plt.ylabel(c_id2)
    plt.xticks(rotation = 90)
    plt.colorbar()
    plt.show()

# %%
get_scatter_plot2('Company Name', 'Price', 'Rating', 'Review Votes')

# %%
def get_line_plot(c_id1,c_id2):
    # Scatter plot with day against tip
    plt.plot(df[c_id1])
    plt.plot(df[c_id2])
    # Adding Title to the Plot
    plt.title("Line Plot")
    # Setting the X and Y labels
    plt.xlabel(c_id1)
    plt.ylabel(c_id2)
    #plt.xticks(rotation = 90)
    plt.show()

# %%
get_line_plot('Company Name','Price')

# %%
get_line_plot('Company Name','Rating')

# %%
get_line_plot('Company Name', 'Review Votes')

# %%
def get_his_plot(c_id1):
    # Scatter plot with day against tip
    plt.hist(df[c_id1])
    # Adding Title to the Plot
    plt.title("Histogram")
    #plt.xticks(rotation = 90)
    plt.show()# reading the database

# %%
get_his_plot('Price')

# %%
get_his_plot('Rating')

# %%
get_his_plot('Review Votes')
